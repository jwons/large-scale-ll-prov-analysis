# %% [markdown]
# # Scripts that might have encountered rdtLite errors
#
# These scripts had 'abnormal' details in their provenance including zero procedure nodes or zero data nodes in the presence of multiple procedure nodes.

# %%
import pandas as pd
prov_df = pd.read_csv("../output/raw_prov_table.csv")

# %%
missing_nodes_df = prov_df[(prov_df.num_of_proc_nodes == 0) | (prov_df.num_of_data_nodes == 0)][["doi", "script_name", "num_of_proc_nodes", "num_of_data_nodes"]]
missing_nodes_df.to_csv("../output/missing_nodes.csv", index=False)
missing_nodes_df
# Out:
#                           doi                             script_name  \
# 10     doi:10.7910/DVN/P1X0GV                 reshuffles_robustness.R
# 11     doi:10.7910/DVN/P1X0GV                   reshuffles_analysis.R
# 12     doi:10.7910/DVN/P1X0GV           reshuffles_further_analysis.R
# 53     doi:10.7910/DVN/HE9H8U                   get_adm_data_cancer.R
# 56     doi:10.7910/DVN/HE9H8U  fig_60_days_after_admission_revision.R
# ...                       ...                                     ...
# 12026  doi:10.7910/DVN/QHCTDX             Code_ENDIREH2003_setupDta.R
# 12034  doi:10.7910/DVN/4YU9LJ                      pc_uk_robustness.R
# 12035  doi:10.7910/DVN/4YU9LJ                             pc_uk_sem.R
# 12039  doi:10.7910/DVN/4YU9LJ                        pc_uk_analysis.R
# 12041  doi:10.7910/DVN/4YU9LJ                  pc_uk_factoranalysis.R
#
#        num_of_proc_nodes  num_of_data_nodes
# 10                     8                  0
# ...
